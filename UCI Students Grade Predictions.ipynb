# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle

# %%
path="/Users/barrett22/Desktop/UCI Student Performance/UCI_Student_Performance/student_mat_2173a47420.csv"
data = pd.read_csv(path, sep=";")
display(data)
data.info()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
data = data[["G1", "G2", "G3", "studytime", "absences", "failures"]]

# %%
predict = "G3"
x = np.array(data.drop([predict], 1))
y = np.array(data[predict])

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x,y,test_size=.1)

# %%
linear = linear_model.LinearRegression()

# %%
linear.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
acc = linear.score(x_test, y_test)
print(acc)
# Out:
# 0.8879728469527121

# %%
print("Co: \n", + linear.coef_)
print("Intercept: \n", + linear.intercept_)
# Out:
# Co:
#  [ 0.15601093  0.97099473 -0.24317279  0.04062515 -0.25012353]
# Intercept:
#  -1.350873652453524

# %%
predictions = linear.predict(x_test)

# %%
for x in range (len(predicitons)):
    print(predictions[x], x_test[x], y_test[x])
# Out:
# 12.813854342979116 [13 13  2  0  0] 13
# 9.508176099772111 [11 10  3  4  0] 11
# 12.58308278585102 [11 13  2  2  0] 14
# 11.699249919366885 [10 12  1  2  0] 12
# 5.808647587895021 [7 7 3 0 0] 8
# 15.704310616407932 [17 15  1  2  0] 15
# 12.339448924478951 [10 13  2  6  1] 13
# 8.792755398992007 [9 9 1 6 0] 10
# 11.162730607433357 [12 11  2 11  0] 11
# 8.309585754214307 [ 7 10  4  2  1] 10
# 15.630706207230533 [16 15  3 16  0] 15
# 10.157022289364654 [11 10  1  8  0] 10
# 10.566332695551568 [10 11  2  4  0] 9
# 10.722343624643804 [11 11  2  4  0] 11
# 11.911708676291896 [15 12  3  0  0] 14
# 12.002301313055042 [14 11  1 18  0] 13
# 9.432837362307017 [10 10  2  0  0] 10
# 7.009608782687627 [ 6  8  1 16  3] 8
# 16.350882252743453 [17 16  2  0  0] 16
# 5.714073914962499 [7 7 2 4 2] 9
# 15.670753248329488 [16 15  2 11  0] 15
# 11.756275856628893 [14 12  4  6  0] 13
# 14.659250408466564 [15 14  2 20  1] 13
# 10.580840131661516 [ 9  9  2 56  0] 8
# 10.544499926811278 [13 10  2 22  1] 11
# ...
